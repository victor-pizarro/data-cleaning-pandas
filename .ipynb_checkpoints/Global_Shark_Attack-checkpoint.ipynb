# %%
# Librearias
import pandas as pd
import numpy as np
import seaborn as sns
import regex as re
import matplotlib.pyplot as plt

from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
# Leemos el dataframe y mostramos los 10 primeros registros.
# Mediante pd.set_option('display.max_columns'None) podremos observar todas las columnas del dataframe.
shark_df=pd.read_csv('attacks.csv', encoding='unicode_escape')
pd.set_option('display.max_columns',None)
shark_df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Cantida de registros no nulos que tengo por columna
shark_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
# Creamos una copia para no sobreescribir el dataframe original
sharks_attacks=shark_df.copy()
sharks_attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
# Identificar duplicados en el dataframe
sharks_attacks.duplicated().sum()
# Out:
# 19411

# %%
# Eliminar duplicados
sharks_attacks.drop_duplicates(inplace=True)
sharks_attacks.duplicated().sum()
# Out:
# 0

# %%
sharks_attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Detección de missing data, son aquellas celdas en las que no se guarda ningun valor de dato.
sharks_attacks.isnull().sum()
# Out:
# Case Number                  2
# Date                        10
# Year                        12
# Type                        14
# Country                     60
# Area                       465
# Location                   550
# Activity                   554
# Name                       220
# Sex                        575
# Age                       2841
# Injury                      38
# Fatal (Y/N)                549
# Time                      3364
# Species                   2848
# Investigator or Source      27
# pdf                         10
# href formula                11
# href                        10
# Case Number.1               10
# Case Number.2               10
# original order               3
# Unnamed: 22               6311
# Unnamed: 23               6310
# dtype: int64

# %%
# Columnas de mi data frame
print(f'Estas son los campos/columnas de mi dataset: \n {sharks_attacks.columns} \n ')

# Normalizar los nombres de las columnas, evitando que tengan espacios en ambos lados y capitalizandolos (primera letra en mayus)

# Creamos una lista con los nombres iniciales y otra para añadir los nombres normalizados
lista_columnas=list(sharks_attacks.columns)
lista_columnas_normalizadas=[]

# Iteramos en la lista inicial para poder quitar espacios y capitalizar, posteriormente añadimos a la lista de columnas normalizadas
for i in lista_columnas:
    lista_columnas_normalizadas.append(i.strip().capitalize())
print(f'Estas son los campos/columnas de mi dataset normalizado: \n {lista_columnas_normalizadas} \n ')
sharks_attacks.columns=lista_columnas_normalizadas

print(f'Así se vé el DataSet con los nombres de las columnas normalizadas:')
sharks_attacks.head()
# Out:
# Estas son los campos/columnas de mi dataset:
#  Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')
#
# Estas son los campos/columnas de mi dataset normalizado:
#  ['Case number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (y/n)', 'Time', 'Species', 'Investigator or source', 'Pdf', 'Href formula', 'Href', 'Case number.1', 'Case number.2', 'Original order', 'Unnamed: 22', 'Unnamed: 23']
#
# Así se vé el DataSet con los nombres de las columnas normalizadas:
#   Case number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# ...

# %% [markdown]
# ## Información por columna

# %% [markdown]
# ### Campo/Columna:    Case number

# %%
# Check data ['Case number'] # ELIMINAR
print(sharks_attacks['Case number'].unique())
print(sharks_attacks["Case number"].value_counts())
print(sharks_attacks["Case number"].isnull().sum())
# Out:
# ['2018.06.25' '2018.06.18' '2018.06.09' ... 'ND.0001' '0' 'xx']
# 0               8
# 1920.00.00.b    2
# 1966.12.26      2
# 2014.08.02      2
# 1990.05.10      2
#                ..
# 1999.09.05      1
# 1999.09.10      1
# 1999.09.16      1
# 1999.09.18      1
# xx              1
# Name: Case number, Length: 6287, dtype: int64
# 2

# %%
# NOTAS, NO TENER EN CUENTA, ESTA COLUMNA SE HA DECIDIDO ELIMINAR!

# Modificaciones sobre la columna, queremos eliminar cualquier letra , para que nos queden únicamente fechas o nans.
#sharks_attacks['Case number']=sharks_attacks['Case number'].replace('[A-Za-z]','', inplace=True)
#sharks_attacks['Case number']
'''
shark_attack_2['Date'].fillna(value=time.today+   ,inplace=True)

shark_attack_2["Date"] = pd.to_datetime(shark_attack_2["Date"], errors ='coerce')
shark_attack_2

pd.to_datetime(shark_attack_2['Date'],errors='ignore',format='%Y/%m/%d')
shark_attack_2

shark_attack_2
'''
# Eliminar las letras que puedan haber:
# Sintaxis: DataFrame.replace(to_replace = None, value = None, inplace = False, limit = None, regex = False, method = 'pad', axis = None)
# sharks_attacks['Case number'].replace(to_replace='[a-zA-Z]', value='',inplace=True,regex=True)

# Eliminar el último punto que queda suelto:

# sharks_attacks['Case number'].replace(to_replace=' ', value='',inplace=True,regex=True)

# ELIMINAR ULTIMO PUNTO!!

# Pasar a formato datetime, en principio formato YY/mm/dd

# SIN ACABAR

#Comprobación:
# sharks_attacks['Case number'].head()
# Out:
# '\nshark_attack_2[\'Date\'].fillna(value=time.today+   ,inplace=True)\n\nshark_attack_2["Date"] = pd.to_datetime(shark_attack_2["Date"], errors =\'coerce\')\nshark_attack_2\n\npd.to_datetime(shark_attack_2[\'Date\'],errors=\'ignore\',format=\'%Y/%m/%d\')\nshark_attack_2\n\nshark_attack_2\n'

# %% [markdown]
# ### Campo/Columna:    Date

# %%
# Check data ['Date']: ELIMINAR COLUMNA, demasiados formatos
'''
print(sharks_attacks['Date'].unique())
print(sharks_attacks["Date"].value_counts())
print(sharks_attacks["Date"].isnull().sum())
'''
# Out:
# '\nprint(sharks_attacks[\'Date\'].unique())\nprint(sharks_attacks["Date"].value_counts())\nprint(sharks_attacks["Date"].isnull().sum())\n'

# %% [markdown]
# ### Campo/Columna:    Year

# %%
# Check data ['Year']:
print(sharks_attacks['Year'].unique())
print(sharks_attacks["Year"].value_counts())
print(sharks_attacks["Year"].isnull().sum())
# Out:
# [2018. 2017.   nan 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008.
#  2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996.
#  1995. 1984. 1994. 1993. 1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986.
#  1985. 1983. 1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973.
#  1972. 1971. 1970. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960.
#  1959. 1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948.
#  1848. 1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937.
#  1936. 1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925.
#  1924. 1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913.
#  1912. 1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901.
#  1900. 1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889.
#  1888. 1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877.
#  1876. 1875. 1874. 1873. 1872. 1871. 1870. 1869. 1868. 1867. 1866. 1865.
# ...

# %%
# Para poder pasar de float64 a int, primero debo eliminar los NaNs:
sharks_attacks['Year'].fillna(0, inplace=True)

# Cambiar de float64 a int para eliminar la coma (decimal)
sharks_attacks['Year']=sharks_attacks['Year'].astype(int,errors='raise')

# Cambiar de int a string
sharks_attacks['Year']=sharks_attacks['Year'].astype(str,errors='raise')

# Asignar el valor np.nan a los ceros (así después podré eliminar registros con dropna())
sharks_attacks['Year'].replace('0',np.nan,inplace=True)

print("El dtype de la serie sharks_attacks['Year'] es tipo:")
print(sharks_attacks['Year'].dtypes)

print('\n')

print("Estos son los valores únicos en mi columna Year:")
print(sharks_attacks['Year'].unique())
# Out:
# El dtype de la serie sharks_attacks['Year'] es tipo:
# object
#
#
# Estos son los valores únicos en mi columna Year:
# ['2018' '2017' nan '2016' '2015' '2014' '2013' '2012' '2011' '2010' '2009'
#  '2008' '2007' '2006' '2005' '2004' '2003' '2002' '2001' '2000' '1999'
#  '1998' '1997' '1996' '1995' '1984' '1994' '1993' '1992' '1991' '1990'
#  '1989' '1969' '1988' '1987' '1986' '1985' '1983' '1982' '1981' '1980'
#  '1979' '1978' '1977' '1976' '1975' '1974' '1973' '1972' '1971' '1970'
#  '1968' '1967' '1966' '1965' '1964' '1963' '1962' '1961' '1960' '1959'
#  '1958' '1957' '1956' '1955' '1954' '1953' '1952' '1951' '1950' '1949'
#  '1948' '1848' '1947' '1946' '1945' '1944' '1943' '1942' '1941' '1940'
#  '1939' '1938' '1937' '1936' '1935' '1934' '1933' '1932' '1931' '1930'
#  '1929' '1928' '1927' '1926' '1925' '1924' '1923' '1922' '1921' '1920'
#  '1919' '1918' '1917' '1916' '1915' '1914' '1913' '1912' '1911' '1910'
#  '1909' '1908' '1907' '1906' '1905' '1904' '1903' '1902' '1901' '1900'
# ...

# %%
# Comprobación de como ha quedado el campo Year:
print(sharks_attacks['Year'].unique())
print(sharks_attacks["Year"].value_counts())
print(sharks_attacks["Year"].isnull().sum())
# Out:
# ['2018' '2017' nan '2016' '2015' '2014' '2013' '2012' '2011' '2010' '2009'
#  '2008' '2007' '2006' '2005' '2004' '2003' '2002' '2001' '2000' '1999'
#  '1998' '1997' '1996' '1995' '1984' '1994' '1993' '1992' '1991' '1990'
#  '1989' '1969' '1988' '1987' '1986' '1985' '1983' '1982' '1981' '1980'
#  '1979' '1978' '1977' '1976' '1975' '1974' '1973' '1972' '1971' '1970'
#  '1968' '1967' '1966' '1965' '1964' '1963' '1962' '1961' '1960' '1959'
#  '1958' '1957' '1956' '1955' '1954' '1953' '1952' '1951' '1950' '1949'
#  '1948' '1848' '1947' '1946' '1945' '1944' '1943' '1942' '1941' '1940'
#  '1939' '1938' '1937' '1936' '1935' '1934' '1933' '1932' '1931' '1930'
#  '1929' '1928' '1927' '1926' '1925' '1924' '1923' '1922' '1921' '1920'
#  '1919' '1918' '1917' '1916' '1915' '1914' '1913' '1912' '1911' '1910'
#  '1909' '1908' '1907' '1906' '1905' '1904' '1903' '1902' '1901' '1900'
#  '1899' '1898' '1897' '1896' '1895' '1894' '1893' '1892' '1891' '1890'
# ...

# %% [markdown]
# ### Campo/Columna:    Type

# %%
# Check data ['Type']
print('Este es el value_counts() inicial:')
#print(sharks_attacks['Type'].unique())
print(sharks_attacks["Type"].value_counts())
# print(sharks_attacks["Type"].isnull().sum())
# Out:
# Este es el value_counts() inicial:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
sharks_attacks["Type"].replace(["Boat", "Boatomg"], "Boating", inplace=True)
sharks_attacks["Type"].replace(["Questionable"], "Invalid", inplace=True)

print('Este es el value_counts() tras relizar las modificaciones:')
print(sharks_attacks["Type"].value_counts())
# Out:
# Este es el value_counts() tras relizar las modificaciones:
# Unprovoked      4595
# Provoked         574
# Invalid          549
# Boating          341
# Sea Disaster     239
# Name: Type, dtype: int64

# %% [markdown]
# ### Campo/Columna:    Country

# %%
# Check data ['Country']
# print(sharks_attacks['Country'].unique())
print(sharks_attacks["Country"].value_counts())
print(sharks_attacks["Country"].isnull().sum())
# Out:
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: Country, Length: 212, dtype: int64
# 60

# %%
# Quitamos espacios a los lados:
sharks_attacks['Country']=sharks_attacks['Country'].str.strip()

# Ponemos todas las letras en mayúsuclas:
sharks_attacks['Country']=sharks_attacks['Country'].str.upper()

# Sustituimos el [?] por nada, es un modo de eliminarlo:
sharks_attacks['Country'].replace(to_replace='[?]', value='',inplace=True,regex=True)

# Cambiar algunos campos:
sharks_attacks['Country']=sharks_attacks['Country'].replace('ST HELENA, BRITISH OVERSEAS TERRITORY','BRITISH VIRGIN ISLANDS')
sharks_attacks['Country']=sharks_attacks['Country'].replace('UNITED ARAB EMIRATES (UAE)','UNITED ARAB EMIRATES')
sharks_attacks['Country']=sharks_attacks['Country'].replace('EGYPT / ISRAEL','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTHERN ARABIAN SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTH ATLANTIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('SOUTH CHINA SEA','CHINA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('WESTERN SAMOA','SAMOA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('RED SEA / INDIAN OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('PACIFIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('BRITISH ISLES','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NEW BRITAIN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('GUINEA','PAPUA NEW GUINEA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTH SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('AMERICAN SAMOA','SAMOA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTH ATLANTIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('THE BALKANS','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('INDIAN OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NETHERLANDS ANTILLES','NETHERLANDS')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTHERN MARIANA ISLANDS','MARIANA ISLANDS')
sharks_attacks['Country']=sharks_attacks['Country'].replace('IRAN / IRAQ','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('CENTRAL PACIFIC','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('SOLOMON ISLANDS / VANUATU','SOLOMON ISLANDS')
sharks_attacks['Country']=sharks_attacks['Country'].replace('SOUTHWEST PACIFIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('MID-PACIFC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('ITALY / CROATIA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('REUNION ISLAND','FRANCE')
sharks_attacks['Country']=sharks_attacks['Country'].replace('CRETE','GREECE')
sharks_attacks['Country']=sharks_attacks['Country'].replace('WEST INDIES','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('EQUATORIAL GUINEA / CAMEROON','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('TOBAGO','TRINIDAD & TOBAGO')
sharks_attacks['Country']=sharks_attacks['Country'].replace('AFRICA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('COAST OF AFRICA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('TASMAN SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('MEDITERRANEAN SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('RED SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('ASIA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('CEYLON (SRI LANKA)','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('ATLANTIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('DIEGO GARCIA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('PALESTINIAN TERRITORIES','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('TURKS & CAICOS','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('CARIBBEAN SEA','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('SOUTH PACIFIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NEW GUINEA','PAPUA NEW GUINEA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('NORTH PACIFIC OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('BAY OF BENGAL','INDIA')
sharks_attacks['Country']=sharks_attacks['Country'].replace('OCEAN','UNDEFINED')
sharks_attacks['Country']=sharks_attacks['Country'].replace('BETWEEN PORTUGAL & INDIA','UNDEFINED')

# %%
# print(sharks_attacks['Country'].unique())
print(sharks_attacks["Country"].value_counts())
print(sharks_attacks["Country"].isnull().sum())
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     147
# NEW ZEALAND          128
#                     ...
# NETHERLANDS            1
# MARIANA ISLANDS        1
# JAVA                   1
# SLOVENIA               1
# KOREA                  1
# Name: Country, Length: 154, dtype: int64
# 60

# %% [markdown]
# ### Campo/Columna:    Area

# %%
# Check data ['Area'] # ELIMINAR COLUMNA
# print(sharks_attacks['Area'].unique())
print(sharks_attacks["Area"].value_counts())
print(sharks_attacks["Area"].isnull().sum())
# Out:
# Florida                                 1037
# New South Wales                          486
# Queensland                               311
# Hawaii                                   298
# California                               290
#                                         ...
# Ysabel Island                              1
#  Lau Province                              1
# South Coast, East New Britain              1
# Between Southampton & Canary Islands       1
# Moala Island                               1
# Name: Area, Length: 825, dtype: int64
# 465

# %% [markdown]
# ### Campo/Columna:    Location

# %%
# Check data ['Location'] # ELIMINAR COLUMNA
# print(sharks_attacks['Location'].unique())
print(sharks_attacks["Location"].value_counts())
print(sharks_attacks["Location"].isnull().sum())
# Out:
# New Smyrna Beach, Volusia County                  163
# Daytona Beach, Volusia County                      30
# Ponce Inlet, Volusia County                        20
# Melbourne Beach, Brevard County                    18
# Myrtle Beach, Horry County                         17
#                                                  ...
# Whale Beach                                         1
# l'Anse-Vata                                         1
# Hole-in-the Wall                                    1
# Wreck of the Navy Barge, 22 miles SE of Rudee       1
# Below the English fort, Trincomalee                 1
# Name: Location, Length: 4108, dtype: int64
# 550

# %% [markdown]
# ### Campo/Columna:    Activity

# %%
# Check data ['Activity']
print(sharks_attacks['Activity'].unique())
print(sharks_attacks["Activity"].value_counts().head(15))
print(sharks_attacks["Activity"].isnull().sum())

# Muy interesante, creo que deberíamos eliminar todos aquellos que no sean los principales, si no corresponden a los más comunes, asignarlos como 'Otras actividedes'
# Out:
# ['Paddling' 'Standing' 'Surfing' ...
#  'Crew swimming alongside their anchored ship' '4 men were bathing'
#  'Wreck of  large double sailing canoe']
# Surfing           971
# Swimming          869
# Fishing           431
# Spearfishing      333
# Bathing           162
# Wading            149
# Diving            127
# Standing           99
# Snorkeling         89
# Scuba diving       76
# Body boarding      61
# Body surfing       49
# Swimming           47
# Kayaking           33
# Treading water     32
# Name: Activity, dtype: int64
# 554

# %% [markdown]
# ### Campo/Columna:    Name

# %%
# Check data ['Name'] # ELIMINAR COLUMNA
# print(sharks_attacks['Name'].unique())
print(sharks_attacks["Name"].value_counts())
print(sharks_attacks["Name"].isnull().sum())
# Out:
# male                               550
# female                              97
# boy                                 23
# 2 males                             16
# boat                                14
#                                   ...
# Jeremiah Wyche                       1
# Frederico Nóbrega (aka Derico)       1
# Joo Whan Hong                        1
# Alton Cicero da Silva                1
# Jules Patterson                      1
# Name: Name, Length: 5230, dtype: int64
# 220

# %% [markdown]
# ### Campo/Columna:    Sex

# %%
# Check data ['Sex']
print(sharks_attacks['Sex'].unique())
print(sharks_attacks["Sex"].value_counts())
print(sharks_attacks["Sex"].isnull().sum())
# Out:
# ['F' 'M' nan 'M ' 'lli' 'N' '.']
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex, dtype: int64
# 575

# %%
# Quitamos los espacios a ambos lados:
sharks_attacks['Sex']=sharks_attacks['Sex'].str.strip()

# Substituimos los valores N por M:
sharks_attacks["Sex"].replace(["N"], ["M"], inplace=True)

# Cambiamos todos aquellos valores distintos de M o F a np.nan (nullos)
sharks_attacks["Sex"].replace(['.'], np.nan , inplace=True)
sharks_attacks["Sex"].replace(['lli'], np.nan , inplace=True)

sharks_attacks["Sex"].value_counts()
# Out:
# M    5098
# F     637
# Name: Sex, dtype: int64

# %% [markdown]
# ### Campo/Columna:    Age

# %%
# Check data ['Age'] # ¿¿¿ELIMINAR COLUMNA???
# print(sharks_attacks['Age'].unique())
# print(sharks_attacks["Age"].value_counts())
# print(sharks_attacks["Age"].isnull().sum())

# %% [markdown]
# ### Campo/Columna:    Injury

# %%
# Check data ['Injury'] # ELIMINAR COLUMNA
# print(sharks_attacks['Injury'].unique())
# print(sharks_attacks["Injury"].value_counts())
# print(sharks_attacks["Injury"].isnull().sum())

# %% [markdown]
# ### Campo/Columna:    Fatal (y/n)

# %%
# Check data ['Fatal (y/n)']
print(sharks_attacks['Fatal (y/n)'].unique())
print(sharks_attacks['Fatal (y/n)'].value_counts())
print(sharks_attacks['Fatal (y/n)'].isnull().sum())
# Out:
# ['N' 'Y' nan 'M' 'UNKNOWN' '2017' ' N' 'N ' 'y']
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: Fatal (y/n), dtype: int64
# 549

# %%
# Quitamos los espacios a ambos lados:
sharks_attacks['Fatal (y/n)']=sharks_attacks['Fatal (y/n)'].str.strip()
# Ponemos cualquier letra en mayúsculas:
sharks_attacks['Fatal (y/n)']=sharks_attacks['Fatal (y/n)'].str.upper()
# Substituimos los valores M por N:
sharks_attacks["Fatal (y/n)"].replace(["M"], "N", inplace=True)
# Cambiamos todos aquellos valores distintos de Y o N a np.nan (nullos)
sharks_attacks["Fatal (y/n)"].replace(["2017"], np.nan , inplace=True)
sharks_attacks["Fatal (y/n)"].replace(["UNKNOWN"], np.nan , inplace=True)

print(f'En nuestro dataset tendremos:')
print(sharks_attacks["Fatal (y/n)"].value_counts())
# Out:
# En nuestro dataset tendremos:
# N    4302
# Y    1389
# Name: Fatal (y/n), dtype: int64

# %% [markdown]
# ### Campo/Columna:    Species

# %%
# Check data ['Species']
#print(sharks_attacks['Species'].unique())
print(sharks_attacks['Species'].value_counts().head())
#print(sharks_attacks['Species'].isnull().sum())

# Especies más relevantes:
'''
White shark
Tiger shark
Bull shark
Wobbegong shark
Blacktip shark
Blue shark
'''
# Out:
# White shark                                           163
# Shark involvement prior to death was not confirmed    105
# Invalid                                               102
# Shark involvement not confirmed                        88
# Tiger shark                                            73
# Name: Species, dtype: int64
# '\nWhite shark\nTiger shark\nBull shark\nWobbegong shark\nBlacktip shark\nBlue shark\n'

# %% [markdown]
# ### Campo/Columna:    Time

# %%
# Check data ['Time'] # ELIMINAR COLUMNA
# print(sharks_attacks['Time'].unique())
# print(sharks_attacks['Time'].value_counts())
# print(sharks_attacks['Time'].isnull().sum())

# %% [markdown]
# ### Eliminar columnas no útiles
# La elección se debe únicamente a intentar resolver las hipotesis que nos hemos planteado, en caso de plantear otras hipotesis, puede ser interesante limpiar y hacer uso de otras columnas.

# %%
"""
Los registros/columnas del dataset que no aportan información relevante son las siguientes:
- Investigator or source
- Pdf
- Href formula
- Href
- Case number
- Case number.1
- Case number.2
- Original order
- Unnamed: 23
- Unnamed: 22
Estas no se estudiarán en profundidad
"""
# Out:
# '\nLos registros/columnas del dataset que no aportan información relevante son las siguientes:\n- Investigator or source\n- Pdf\n- Href formula\n- Href\n- Case number\n- Case number.1\n- Case number.2\n- Original order\n- Unnamed: 23\n- Unnamed: 22\nEstas no se estudiarán en profundidad\n'

# %%
# Eliminar campos/columnas que no son de interes:
shark_attack_2=sharks_attacks.drop(['Date','Investigator or source','Pdf','Href formula','Href','Original order','Unnamed: 22', 'Unnamed: 23','Case number.1','Case number.2','Case number','Injury','Age','Time','Name','Area','Location'], axis=1)
shark_attack_2
# Out:
#        Year        Type    Country     Activity  Sex Fatal (y/n)  \
# 0      2018     Boating        USA     Paddling    F           N
# 1      2018  Unprovoked        USA     Standing    F           N
# 2      2018     Invalid        USA      Surfing    M           N
# 3      2018  Unprovoked  AUSTRALIA      Surfing    M           N
# 4      2018    Provoked     MEXICO  Free diving    M           N
# ...     ...         ...        ...          ...  ...         ...
# 6307    NaN         NaN        NaN          NaN  NaN         NaN
# 6308    NaN         NaN        NaN          NaN  NaN         NaN
# 6309    NaN         NaN        NaN          NaN  NaN         NaN
# 8702    NaN         NaN        NaN          NaN  NaN         NaN
# 25722   NaN         NaN        NaN          NaN  NaN         NaN
#
#                Species
# 0          White shark
# 1                  NaN
# 2                  NaN
# 3            2 m shark
# 4      Tiger shark, 3m
# ...                ...
# ...

# %%
shark_attack_2.dropna(how='all',inplace=True)
shark_attack_2
# Out:
#       Year        Type    Country      Activity Sex Fatal (y/n)  \
# 0     2018     Boating        USA      Paddling   F           N
# 1     2018  Unprovoked        USA      Standing   F           N
# 2     2018     Invalid        USA       Surfing   M           N
# 3     2018  Unprovoked  AUSTRALIA       Surfing   M           N
# 4     2018    Provoked     MEXICO   Free diving   M           N
# ...    ...         ...        ...           ...  ..         ...
# 6297   NaN  Unprovoked  AUSTRALIA        Diving   M           Y
# 6298   NaN  Unprovoked  AUSTRALIA  Pearl diving   M           Y
# 6299   NaN  Unprovoked        USA      Swimming   M           Y
# 6300   NaN  Unprovoked     PANAMA           NaN   M           Y
# 6301   NaN  Unprovoked  UNDEFINED      Swimming   M           Y
#
#               Species
# 0         White shark
# 1                 NaN
# 2                 NaN
# 3           2 m shark
# 4     Tiger shark, 3m
# ...               ...
# 6297              NaN
# ...

# %% [markdown]
# ### Analisis de datos

# %% [markdown]
# ### Hipotesis

# %%
'''
Hipotesis nº1

Al realizar la limpieza y manipulación del dataset, perderemos aproximadamente el 40% de este.


dataset inicial: 25723 x 24 (registros x campos)
dataset final:   6302  x 7  (registros x campos)

Como se observa, perdemos una gran cantidad de registros.

'''
num_reg_inicial=25723
num_reg_final=6302

ratio=num_reg_final/num_reg_inicial

ratio_redondeado=round(ratio,3)

print(f'Tras la limpieza y manipulación de datos nos hemos quedado con el {ratio_redondeado*100}% del dataset inicial \n Por lo tanto, nuestra hipotesis es erronea, hemos perdido el {(1-(ratio_redondeado))*100}%')
# Out:
# Tras la limpieza y manipulación de datos nos hemos quedado con el 24.5% del dataset inicial
#  Por lo tanto, nuestra hipotesis es erronea, hemos perdido el 75.5%

# %%
'''
Hipotesis nº2
Consideramos que debido a la gran extensión de costa, los tres países con mayor número de ataques serán en orden:
1. Estados Unidos - USA
2. Australia
3. Brasil

Descartamos países como Canada y Rusia ya que mucha de la costa perteneciente a dichos países se encuentran en unas latitudes extremas,
donde se hace practicamente inexistente la presencia de tiburones.

'''
tabla_frecuencia_paises=pd.crosstab(shark_attack_2['Country'],'Ataques')
tabla_frecuencia_paises.sort_values('Ataques',ascending=False)
# Out:
# col_0              Ataques
# Country
# USA                   2229
# AUSTRALIA             1338
# SOUTH AFRICA           579
# PAPUA NEW GUINEA       147
# NEW ZEALAND            128
# ...                    ...
# GRAND CAYMAN             1
# GHANA                    1
# SLOVENIA                 1
# GABON                    1
# ADMIRALTY ISLANDS        1
#
# [154 rows x 1 columns]

# %%
# Ejemplo 1
tabla_frecuencia_paises.sort_values('Ataques',ascending=False).head(7).plot.bar()
plt.savefig("hipotesis_1_vertical.jpg")

# %%
# Ejemplo 2
shark_attack_2['Country'].value_counts().head(7).sort_values().plot(kind='barh')
plt.savefig("hipotesis_1_horizontal.jpg",bbox_inches='tight')

# %%
# Estudiaremos la letalidad de los 3 países con mayores ataques.

# Fatal (y/n) - USA

shark_attack_2[shark_attack_2['Country']=='USA']['Fatal (y/n)'].value_counts().plot.pie(figsize=(5, 5))
plt.savefig("Fatal_USA.jpg")

print(f'La probabilidad de que un ataque sea letal en USA es de {round((186/(186+1837))*100,2)}%')
print(shark_attack_2[shark_attack_2['Country']=='USA']['Fatal (y/n)'].value_counts())
# Out:
# La probabilidad de que un ataque sea letal en USA es de 9.19%
# N    1837
# Y     186
# Name: Fatal (y/n), dtype: int64

# %%
# Fatal (y/n) - AUSTRALIA

shark_attack_2[shark_attack_2['Country']=='AUSTRALIA']['Fatal (y/n)'].value_counts().plot.pie(figsize=(5, 5))
plt.savefig("Fatal_AUSTRALIA.png")

print(f'La probabilidad de que un ataque sea letal en AUSTRALIA es de {round((283/(283+921))*100,2)}%')
print(shark_attack_2[shark_attack_2['Country']=='AUSTRALIA']['Fatal (y/n)'].value_counts())
# Out:
# La probabilidad de que un ataque sea letal en AUSTRALIA es de 23.5%
# N    921
# Y    283
# Name: Fatal (y/n), dtype: int64

# %%
# Fatal (y/n) - SOUTH_AFRICA

shark_attack_2[shark_attack_2['Country']=='SOUTH AFRICA']['Fatal (y/n)'].value_counts().plot.pie(figsize=(5, 5))
plt.savefig("Fatal_SOUTH_AFRICA.jpg")

print(f'La probabilidad de que un ataque sea letal en SOUTH AFRICA es de {round((106/(106+407))*100,2)}%')
print(shark_attack_2[shark_attack_2['Country']=='SOUTH AFRICA']['Fatal (y/n)'].value_counts())
# Out:
# La probabilidad de que un ataque sea letal en SOUTH AFRICA es de 20.66%
# N    407
# Y    106
# Name: Fatal (y/n), dtype: int64

# %%
# Hipotesis 3:
'''
White shark
Tiger shark
Bull shark
Wobbegong shark
Blacktip shark
Blue shark
'''

import numpy as np
import matplotlib.pyplot as plt
grupos = ['White', 'Tiger', 'Bull', 'Wobbegong','Blacktip','Blue']
Letal = [44,25,15,0,0,4]
No_letal = [114,48,36,20,15,10]
 
indice = np.arange(len(grupos))
 
## Se crean las primeras barras
plt.bar(indice, Letal, label='Letal')
 
## Se crean las segundas barras y se apilan sobre las primeras
plt.bar(indice, No_letal, label='No letal',  bottom=Letal)
 
plt.xticks(indice, grupos)
plt.ylabel("Cantidad de ataques")
plt.xlabel("Especies")
plt.title('Letalidad por especie')
plt.legend()
 
plt.show()

plt.savefig("letalidad_por_especie.jpg",bbox_inches='tight')

# %%
'''
White shark
Tiger shark
Bull shark
Wobbegong shark
Blacktip shark
Blue shark

Cual es por tipo la frecuencia máxima de tiburones dispuestos a morder a esta chiquilla, ni idea, esto borralo;

'''
# Comprobar cuantos Y y N hay por especie:
print('White shark')
print(shark_attack_2[shark_attack_2['Species']=='White shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(44/(114+44),3)*100}')

print(' \n Tiger shark')
print(shark_attack_2[shark_attack_2['Species']=='Tiger shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(25/(48+25),3)*100}')

print(' \n Bull shark')
print(shark_attack_2[shark_attack_2['Species']=='Bull shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(15/(36+15),3)*100}')

print(' \n Wobbegong shark')
print(shark_attack_2[shark_attack_2['Species']=='Wobbegong shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(0/(20+0),3)*100}')

print(' \n Blacktip shark')
print(shark_attack_2[shark_attack_2['Species']=='Blacktip shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(0/(15+0),3)*100}')

print(' \n Blue shark')
print(shark_attack_2[shark_attack_2['Species']=='Blue shark']['Fatal (y/n)'].value_counts())
print(f'Su ratio de fatalidad es de {round(4/(10+4),3)*100}')
# Out:
# White shark
# N    114
# Y     44
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 27.800000000000004
#
#  Tiger shark
# N    48
# Y    25
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 34.2
#
#  Bull shark
# N    36
# Y    15
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 29.4
#
#  Wobbegong shark
# N    20
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 0.0
#
#  Blacktip shark
# N    15
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 0.0
#
#  Blue shark
# N    10
# Y     4
# Name: Fatal (y/n), dtype: int64
# Su ratio de fatalidad es de 28.599999999999998

# %%
'''
Hipotesis 4

Las actividades asociadas al mayor número de ataques son:
1. Nadar
2. Bucear
3. Surfear

Se han escogido estas actividades porque son aquellas en las cuales el ser humano se siente más vulnerable,
por eso se han escogido de mayor riesgo a menor riesgo las tres primeras actividades con mayor riesgo.

'''
# Out:
# '\nHipotesis 4\n\nLas actividades asociadas al mayor número de ataques son:\n1. Nadar\n2. Bucear\n3. Surfear\n\nSe han escogido estas actividades porque son aquellas en las cuales el ser humano se siente más vulnerable,\npor eso se han escogido de mayor riesgo a menor riesgo las tres primeras actividades con mayor riesgo.\n\n'

# %%
shark_attack_2['Activity'].value_counts().head(10).sort_values().plot(kind='barh')
plt.savefig("Actividad_horizontal.jpg")

# %%
tabla_frecuencia_paises=pd.crosstab(shark_attack_2['Activity'],'Actividades')
(tabla_frecuencia_paises.sort_values('Actividades',ascending=False))
tabla_frecuencia_paises.sort_values('Actividades',ascending=False).head(10).plot.bar()
plt.savefig("Actividad_vertical.jpg")
